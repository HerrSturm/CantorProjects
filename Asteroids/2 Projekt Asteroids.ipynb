# %% [markdown]
# # Projekt Asteroids
#
# Programmiere Asteroids. Bei diesem Spiel steuerst du mit den Pfeiltasten ein Raumschiff, das sich im Weltraum bewegt. Das Ziel ist es den Asteroiden auszuweichen. Wird dein Raumschiff getroffen verlierst du ein Leben. Das Spiel soll immer schwieriger werden.
#
# **Achtung**
# Wir zerlegen das Projekt in mehrere Teilschritte. Wenn du das Spiel starten willst, starte **alle** Zellen. Wähle dazu den ⏩ Button oden zum Starten oder klicke auf Run -> Run all Cells.
#
# Es folgt der erste Block, an dem du nichts machen musst. Dieser definiert das Fenster.

# %%
import pygame, sys
import random

# Initialisierung von Pygame
pygame.init()

# Bildschirmgröße
breite = 800
hoehe = 600

# Farben
black = (0, 0, 0)
white = (255, 255, 255)

# Schriftart und Größe festlegen
font = pygame.font.SysFont(None, 48)

# Spielbildschirm erstellen
screen = pygame.display.set_mode((breite, hoehe))
pygame.display.set_caption("Asteroids")

#Variablen und Clock definieren
clock = pygame.time.Clock()

# %% [markdown]
# ### Task 1: Asteroiden erzeugen und in einer Liste speichern
#
# Erstelle eine Liste mit mehreren Hitboxen.
# > Du kannst mit Hilfe von `liste.append(element)` ein Element einer Liste hinzufügen.
# > Mit Hilfe von `pygame.Rect(x-Position,y-Position,Länge,Breite)` erstellst du eine Hitbox.
# > Mit `screen.blit(Bild, Hitbox)` zeichnest du ein vorher geladenes Bild in die entsprechende Hitbox. Achte darauf, dass Bild und Hitbox übereinstimmen.
# > Du kannst mit `pygame.transform.scale(Bild, (Länge, Breite))` ein Bild auf angegebene Länge und Breite skalieren.

# %%
#Hintergrund
#?bg=pygame.image.load("background1.png")
#?bg=pygame.transform.scale(bg,(800,600))
#?screen.blit(bg, (0, 0))
# Grafiken laden
asteroidIMGk = pygame.image.load("asteroid.png")
asteroidIMGg = pygame.image.load("asteroid.png")
asteroidIMGm = pygame.image.load("asteroid.png")
bg = pygame.image.load("background3.png")
schussIMG = pygame.image.load("Schuss.png")


#Größe der Bilder anpassen
k=20
m=30
g=50
asteroidIMGk = pygame.transform.scale(asteroidIMGk, (k, k))
asteroidIMGm = pygame.transform.scale(asteroidIMGm, (m, m))
asteroidIMGg = pygame.transform.scale(asteroidIMGg, (g, g))
bg = pygame.transform.scale(bg, (800,600))
schussIMG= pygame.transform.scale(schussIMG, (20,20))
#Erstellt eine leere Liste für die Asteroiden
asteroidList = []
schussList=[]
#Füge hier Asteroiden in die Liste ein:
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),k,k))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),k,k))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),k,k))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),k,k))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),k,k))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),k,k))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),k,k))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),m,m))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),m,m))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),m,m))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),m,m))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),m,m))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),m,m))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),m,m))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),m,m))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),m,m))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),m,m))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),m,m))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),g,g))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),g,g))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),g,g))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),g,g))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),g,g))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),g,g))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),g,g))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),g,g))
asteroidList.append(pygame.Rect(random.randint(300,1200),random.randint(0,600),g,g))



#Ersetze das pass mit Logik um die Asteroiden an Stelle der Hitbox zu zeichnen.
#Gehe dazu die Liste mit Hilfe der for-Schleife durch.
def renderAsteroids(asteroidList):
    for asteroid in range(len(asteroidList)):
        if asteroid <= 6:
            screen.blit(asteroidIMGk, asteroidList[asteroid])
        if asteroid > 6 and asteroid <=17:
            screen.blit(asteroidIMGm, asteroidList[asteroid])
        if asteroid >17:
            screen.blit(asteroidIMGg, asteroidList[asteroid])
    return()

# %% [markdown]
# ### Task 2: Asteroiden bewegen
# Lasse die Asteroiden über den Bildschirm von links nach rechts bewegen. Ergänze Logik, die die Asteroiden wieder zurücksetzt, wenn sie aus dem Bildschirm raus fliegen.
# > Nutze `asteroid.move_ip(x,y)` zur Bewegung.
# > Mit `asteroid.x` bzw. `asteroid.y` kannst du auf die Koordinaten der Asteroiden zurückgreifen.
#
#
# Ersetze das `pass` mit Logik. Du kannst beliebig viele Zeilen einfügen.
# > **Hinweis:** Eine for-Schleife wird benötigt um die Liste durchzugehen.
#
# > **Erklärung:** `pass` dient dazu etwas zu überspringen. Man nutzt es um eine Programmierstruktur anzulegen, die später programmiert werden soll. Nutzt man `pass`, lässt sich das Programm dennoch ausführen. Eine leere Schleife beispielsweise würde einen Fehler bei der Ausführung erzeugen.

# %%
#Bewegung der Asteroiden
def moveAsteroids(asteroidList):
    for asteroid in asteroidList:
        asteroid.move_ip(-s,0)
    return()

# %% [markdown]
# ### Task 3: Spaceship zeichnen und bewegen
#
# 1. Erstelle eine Hitbox für das Spaceship und zeichne es.
# 2. Programmiere die Logik für die Bewegung des Spaceships.

# %%
#Grafiken laden
spaceshipIMG = pygame.image.load("spaceship.png")
spaceshipIMG = pygame.transform.scale(spaceshipIMG, (40, 40))
#Hitbox für das Spaceship erzeugen (Ersetze das None):
spaceship = pygame.Rect(100,300,40,40)

#Spaceship zeichnen:

def drawSpaceship(spaceship):
    screen.blit(spaceshipIMG, spaceship)
    return()


def moveSpaceship(spaceship):
    # Ermittelt die gedrückten Tasten
    keys = pygame.key.get_pressed()
    #Programmiere die Steuerung nach dem Muster:
    if keys[pygame.K_LEFT] and spaceship.x>10:
        spaceship.move_ip(-10,0)
    if keys[pygame.K_RIGHT] and spaceship.x<745:
        spaceship.move_ip(10,0)
    if keys[pygame.K_DOWN] and spaceship.y<545:
        spaceship.move_ip(0,10)
    if keys[pygame.K_UP] and spaceship.y>10:
        spaceship.move_ip(0,-10)

# %% [markdown]
# ### Task 4: Treffer?
#
# 1. Überprüfe, ob einer der Asteroiden das Spaceship trifft. Ziehe ein Leben ab, wenn das Raumschiff getroffen wird.
# > Du brauchst wieder eine for-Schleife und ein `if`.
# > Mit `spaceShip.colliderect(asteroid)` lässt sich überprüfen, ob **ein** Asteroid das Raumschiff trifft. Das musst du für alle Asteroiden der Liste überprüfen.
#
# **Hinweise:**
# > Mit Hilfe von `break` lässt sich eine Schleife abbrechen. Das kann man nutzen, um die Schleife zu unterbrechen, wenn ein Asteroid das Raumschiff getroffen hat.
#
# > Nach einem Treffer sollte man den Asteroiden versetzen, sonst wird im nächsten Frame dieser wieder das Raumschiff treffen.
#
# 2. Programmiere die Score-Anzeige. Du darfst die Anzahl der Hitpoints gerne verändern.
#
# > Mit `text = font.render(Text, True, Farbe)` lässt sich ein Text erzeugen.
# > Diesen kannst du mit `screen.blit(text, (x-Position, y-Position))` anzeigen lassen.

# %%
hitpoints = 3

# Programmiere hier die Überprüfung, ob das Raumschiff einen Asteroiden trifft und programmiere die Logik, 
# was passieren soll, wenn das der Fall ist. 
def checkCollision(hitpoints,spaceship,asteroidList):
    for asteroid in asteroidList:
        if spaceship.colliderect(asteroid):
            hitpoints -= 1
            asteroid.x=random.randint(900,1300)
            asteroid.y=random.randint(0,600)
        if asteroid.x <1:
            asteroid.x=random.randint(900,1300)
            asteroid.y=random.randint(0,600)
    return(hitpoints)

#Definiert eine Schriftart und Schriftgröße für das Spiel
font = pygame.font.SysFont(None, 48)

# Programmiere hier die Score-Anzeige
def renderHitpoints(hitpoints,font):
    text = font.render(f"Leben:{hitpoints}", True, white)
    screen.blit(text, (100, 100))
    #pass
    return()

# %% [markdown]
# ### Task 5: Score und Game-Over
#
# Erweitere das Programm, so dass der Score konstant steigt und die zurückgelegte Strecke darstellt.

# %%
def renderScore(score):
    textt = font.render(f"Score:{score}", True, white)
    screen.blit(textt, (400, 100))
    return()

score = 0

    
# Spielschleife

running = True
c=100
s=5
while running:
    if hitpoints>-1:
        score+=1
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
    keys = pygame.key.get_pressed()
    if keys[pygame.K_ESCAPE]:
        running = False
    #schusscountdown
    c+=1
    #Schnelligkeit Asteroiden
    s = (5+(score//300))
    #Ruft die Spielelogik auf, die du oben programmiert hast
    moveAsteroids(asteroidList)
    moveSpaceship(spaceship)
    hitpoints=checkCollision(hitpoints,spaceship,asteroidList)
    
    # Zeichnungen der Objekte
    # Hier wird alles, was du oben programmiert hast, aufgerufen
    #screen.fill(white)
    gblist=[]
    gblist.append(pygame.Rect(0,0,800,600))
    screen.blit(bg, gblist[0])
    renderAsteroids(asteroidList)
    drawSpaceship(spaceship)
    renderHitpoints(hitpoints, font)
    renderScore(score)
    #Schüsse
    for schuss in schussList:
        schuss.move_ip(5,0)
    if keys[pygame.K_SPACE] and c > 50:
        c=0
        schussList.append(pygame.Rect(spaceship.x,spaceship.y,20,20))
    for schuss in range(len(schussList)):
        screen.blit(schussIMG, schussList[schuss])


    for schuss in schussList:
        for asteroid in asteroidList:
            if asteroid.colliderect(schuss):
                asteroid.x=800
                asteroid.y=random.randint(0,600)
                schuss.x=0
                schuss.y=700
    if hitpoints<0:
        sc=score
        screen.fill(black)
        gameover = font.render("Game Over", True, white)
        screen.blit(gameover, (300, 150))
        scr = font.render(f"Score={sc}", True, white)
        screen.blit(scr, (300, 250))
        
        
    pygame.display.flip()
    clock.tick(30)
 

pygame.quit()
sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %% [markdown]
# ### Weitere Tasks:
#
# 1. Füge Asteroiden in verschiedenen Größen ein. Am besten skalierst du dir die Bilder auf ca. drei verschiedene Größen und erweiterst die Liste, so dass du nicht mehr nur die Rechtecke speicherst, sondern auch die Größe.
# 2. Erweitere das Raumschiff so, dass es schießen kann. Die Schüsse solltest du in einer separaten Liste verwalten. Nutze diese Liste um die Schüsse zu zeichnen.
# 3. Füge einen Hintergrund ein (drei mögliche sind im Ordner enthalten).
#
# (+4.Schneller werdende Asteroiden.)
